# %%
contador = 1

while contador <= 10:
    if contador % 2 == 0:
        print(contador, "es un numero par")
        
    print("Y ahora incremento el contador")
    contador += 1
    
print("Fuera del while")
# Out:
# Y ahora incremento el contador
# 2 es un numero par
# Y ahora incremento el contador
# Y ahora incremento el contador
# 4 es un numero par
# Y ahora incremento el contador
# Y ahora incremento el contador
# 6 es un numero par
# Y ahora incremento el contador
# Y ahora incremento el contador
# 8 es un numero par
# Y ahora incremento el contador
# Y ahora incremento el contador
# 10 es un numero par
# Y ahora incremento el contador
# Fuera del while

# %%
contador = 1

while contador <= 10:
    if contador % 2 == 0:
        print(contador, "es un numero par")
        continue
        
    print("Y ahora incremento el contador")
    contador += 1
    
print("Fuera del while")
# Out:
# Y ahora incremento el contador
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# ...
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# 2 es un numero par
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 3>()
#       3 while contador <= 10:
#       4     if contador % 2 == 0:
# ----> 5         print(contador, "es un numero par")
#       6         continue
#       8     print("Y ahora incremento el contador")
#
# File ~\anaconda3\lib\site-packages\ipykernel\iostream.py:404, in OutStream.write(self, string)
#     402 is_child = (not self._is_master_process())
#     403 # only touch the buffer in the IO thread to avoid races
# --> 404 self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405 if is_child:
#     406     # mp.Pool cannot be trusted to flush promptly (or ever),
#     407     # and this helps.
#     408     if self._subprocess_flush_pending:
#
# File ~\anaconda3\lib\site-packages\ipykernel\iostream.py:205, in IOPubThread.schedule(self, f)
#     203     self._events.append(f)
#     204     # wake event thread (message content is ignored)
# --> 205     self._event_pipe.send(b'')
#     206 else:
#     207     f()
#
# File ~\anaconda3\lib\site-packages\zmq\sugar\socket.py:416, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     413         data = zmq.Frame(data, track=track, copy=copy or None,
#     414                          copy_threshold=self.copy_threshold)
#     415     data.group = group
# --> 416 return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#
# File zmq/backend/cython/socket.pyx:728, in zmq.backend.cython.socket.Socket.send()
#
# File zmq/backend/cython/socket.pyx:775, in zmq.backend.cython.socket.Socket.send()
#
# File zmq/backend/cython/socket.pyx:242, in zmq.backend.cython.socket._send_copy()
#
# File ~\anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd:13, in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
lista = ["hola", "mensaje", "adios"]

for palabra in lista:
    print("Palabra actual:", palabra)

    if palabra == "mensaje":
        print("He encontrado la palabra mensaje")
        break
# Out:
# Palabra actual: hola
# Palabra actual: mensaje
# He encontrado la palabra mensaje

# %%
valor = 5

if valor == 1:
    print("Valor es 1")
elif valor == 2:
    print("Valor es 2")
elif valor == 3:
    print("Valor es 3")
elif valor == 4:
    print("Valor es 4")
elif valor == 5:
    print("Valor es 5")
# Out:
# Valor es 5

# %%
python --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 python --version
#
# NameError: name 'python' is not defined

# %%
valor = 3

match valor:
    case 1:
        print("Valor es 1")
    case 2:
        print("Valor es 2")
    case 3:
        print("Valor es 3")
    case 4:
        print("Valor es 4")
    case 5:
        print("Valor es 5")
# Out:
#   Input In [6]
#     match valor:
#           ^
# SyntaxError: invalid syntax

# %%
lista = ["hola", "mensaje", "adios"]

for palabra in lista:
    if palabra == "mensaje":
        print("Encuentro la palabra mensaje")
        continue
else:
    print("No encuentro nada")
# Out:
# Encuentro la palabra mensaje
# No encuentro nada

# %%
lista = ["hola", "mensaje", "adios"]

for palabra in lista:
    if palabra == "mensaje":
        print("Encuentro la palabra mensaje")
        break
else:
    print("No encuentro nada")
# Out:
# Encuentro la palabra mensaje
